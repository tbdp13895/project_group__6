# %%
import sqlite3
import pandas as pd
import csv

# %%
con = sqlite3.connect('../database/Hospital.db')
cur = con.cursor()

# %%
hospital = pd.read_csv('hospital.csv')
hospital.head(5)
# Out:
#    Provider_ID                     Hospital_Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP_Code County_Name         Hospital_Type  \
# 0  DOTHAN    AL     36301     HOUSTON  Acute Care Hospitals
# 1  DOTHAN    AL     36301     HOUSTON  Acute Care Hospitals
# 2  DOTHAN    AL     36301     HOUSTON  Acute Care Hospitals
# 3  DOTHAN    AL     36301     HOUSTON  Acute Care Hospitals
# 4  DOTHAN    AL     36301     HOUSTON  Acute Care Hospitals
#
#                             Hospital_Ownership  Emergency_Services  \
# 0  Government - Hospital District or Authority                True
# ...

# %%
hospital.to_sql('Hospital', con, if_exists='replace', index=False)
# Out:
# 19468

# %%
rows = cur.execute("SELECT * FROM hospital").fetchall()
rows
# Out:
# [(10001,
#   'SOUTHEAST ALABAMA MEDICAL CENTER',
#   '1108 ROSS CLARK CIRCLE',
#   'DOTHAN',
#   'AL',
#   36301,
#   'HOUSTON',
#   'Acute Care Hospitals',
#   'Government - Hospital District or Authority',
#   1,
#   'CLABSI',
#   2038.0,
#   3.058,
#   7,
#   2.289),
#  (10001,
#   'SOUTHEAST ALABAMA MEDICAL CENTER',
#   '1108 ROSS CLARK CIRCLE',
#   'DOTHAN',
#   'AL',
#   36301,
#   'HOUSTON',
#   'Acute Care Hospitals',
#   'Government - Hospital District or Authority',
#   1,
#   'CAUTI',
#   7310.0,
#   8.779,
#   29,
#   3.303),
#  (10001,
#   'SOUTHEAST ALABAMA MEDICAL CENTER',
#   '1108 ROSS CLARK CIRCLE',
#   'DOTHAN',
#   'AL',
#   36301,
#   'HOUSTON',
#   'Acute Care Hospitals',
#   'Government - Hospital District or Authority',
#   1,
#   'SSI: Colon',
#   156.0,
#   5.2700000000000005,
#   2,
#   0.38),
#  (10001,
#   'SOUTHEAST ALABAMA MEDICAL CENTER',
#   '1108 ROSS CLARK CIRCLE',
#   'DOTHAN',
#   'AL',
#   36301,
#   'HOUSTON',
#   'Acute Care Hospitals',
# ...

# %%
result = pd.read_sql_query("SELECT * FROM hospital", con)

# %%
len(hospital.columns)
# Out:
# 15

# %%
hospital.dtypes
# Out:
# Provider_ID             int64
# Hospital_Name          object
# Address                object
# City                   object
# State                  object
# ZIP_Code                int64
# County_Name            object
# Hospital_Type          object
# Hospital_Ownership     object
# Emergency_Services       bool
# Disease_Name           object
# Days                  float64
# Predicted_Cases       float64
# Observed_Cases          int64
# SIR                   float64
# dtype: object

# %%
hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19468 entries, 0 to 19467
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Provider_ID         19468 non-null  int64
#  1   Hospital_Name       19468 non-null  object
#  2   Address             19468 non-null  object
#  3   City                19468 non-null  object
#  4   State               19468 non-null  object
#  5   ZIP_Code            19468 non-null  int64
#  6   County_Name         19448 non-null  object
#  7   Hospital_Type       19468 non-null  object
#  8   Hospital_Ownership  19468 non-null  object
#  9   Emergency_Services  19468 non-null  bool
#  10  Disease_Name        19468 non-null  object
#  11  Days                19468 non-null  float64
#  12  Predicted_Cases     19468 non-null  float64
#  13  Observed_Cases      19468 non-null  int64
#  14  SIR                 19468 non-null  float64
# ...

# %%
hospital_filt = hospital.loc[:,(-hospital.isnull().any())]

# %%
con.commit()
con.close()
